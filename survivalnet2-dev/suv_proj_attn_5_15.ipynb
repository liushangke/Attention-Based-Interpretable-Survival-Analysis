# %% [markdown]
# ### Installing packages ###

# %%
import numpy as np
import os
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import tensorflow as tf
from tensorflow.keras.layers import Input, Dense, Dropout, GlobalAveragePooling1D
from tensorflow.keras.models import Model

from sklearn.model_selection import KFold
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

import plotly.graph_objects as go
import plotly.subplots as sp
from plotly.subplots import make_subplots

import survivalnet2
from survivalnet2.data.labels import stack_labels, unstack_labels
from survivalnet2.losses import efron, cox
from survivalnet2.metrics.concordance import HarrellsC
from survivalnet2.visualization import km_plot

# Set random seeds for reproducibility
np.random.seed(51)
tf.random.set_seed(51)

# %% [markdown]
# ### Data preprocessing ###

# %%
def binarize_columns(df):
    # binarizr region identifier as 0 or 1
    df[df.columns[0]] = df.iloc[:, 0].apply(lambda x: 1 if x == 'TUMOR' else 0)
    return df

def compute_median_values(data_files):
    # Read in first file to get the columns
    sample = pd.read_csv(data_files[0])
    num_cols = sample.shape[1] - 2  # Exclude the first two columns

    # Initialize array to store values for all files
    values = np.empty((0, num_cols))

    # Iterate over all files and extract values
    for data_file in data_files:
        # Read in data and skip first row (assumed to be header)
        df = pd.read_csv(data_file, skiprows=[0], usecols=range(2, num_cols+2))
        df = binarize_columns(df)
        values = np.concatenate((values, df.values), axis=0)
    
    # Compute median values for each column
    median_values = np.median(values, axis=0)
    median_dict = {sample.columns[i+2]: median_values[i] for i in range(num_cols)}
    return median_dict


def pad_missing_values(df, median_dict):
    # Replace missing values with median value for each column
    for col in df.columns:
        median_value = median_dict[col]
        df[col].fillna(median_value, inplace=True)
    return df


def min_max_normalize_features(df):

    for col in df.columns:
        min_value = df[col].min()
        max_value = df[col].max()
        
        # Check if values are not already in the range [0, 1]
        if (min_value < 0 or max_value > 1):
            df[col] = (df[col] - min_value) / (max_value - min_value)
        
    return df

def create_label_dict(label_dir):
    df = pd.read_csv(label_dir)
    column_names = df.columns  # Get the column names from the first row
    label_dict = {}
    for i in range(1, len(df)):
        name = df.iloc[i, 0]  # Get the sample name from the first column of the current row
        time = df.iloc[i, column_names.get_loc('ClinicalFeats.Survival.BCSS.YearsFromDx')]  # Get the time data from the 'ClinicalFeats.Survival.BCSS.YearsFromDx' column
        event = df.iloc[i, column_names.get_loc('ClinicalFeats.Survival.BCSS')]  # Get the event data from the 'ClinicalFeats.Survival.BCSS' column
        label_dict[name] = (time, event)
    return label_dict

def z_score_normalize_ragged_tensor(ragged_tensor):
    scaler = StandardScaler()

    # Store the lengths of the subtensors before flattening the ragged tensor
    lengths = [len(subtensor) for subtensor in ragged_tensor]

    # Flatten the ragged tensor and convert it to a 2D numpy array
    flat_data = ragged_tensor.to_tensor().numpy().reshape(-1, D)

    # Fit and transform the data using the StandardScaler
    normalized_data = scaler.fit_transform(flat_data)

    # Check if mean is close to 0 and standard deviation is close to 1
    mean = np.mean(normalized_data, axis=0)
    std_dev = np.std(normalized_data, axis=0)

    print("Mean:", mean)
    print("Standard Deviation:", std_dev)
    
    # Restore the original ragged structure
    normalized_data_ragged = []
    start_idx = 0
    for length in lengths:
        normalized_data_ragged.append(normalized_data[start_idx:start_idx+length])
        start_idx += length

    return tf.ragged.constant(normalized_data_ragged, ragged_rank=1, dtype=tf.float32)

# %% [markdown]
# ### Parameters definition ###

# %%
# define dimensionality
D = 49
print(f"Dimensionality of each feature vector is: {D}")

# Define the batch size you want to use
batch_size = 64


data_dir = '/Users/shangke/Desktop/pathology/perSlideRegionFeatures/CPSII_40X'
label_dir = '/Users/shangke/Desktop/pathology/FusedData_CPSII_40X.csv'
csv_names = os.listdir(data_dir)
null_count = 0
label_dict = create_label_dict(label_dir)
valid_csv_names = []

for name in csv_names:
    if name.rstrip('.csv') in list(label_dict.keys()):
        valid_csv_names.append(name)

    else:
        null_count += 1

data_files = [os.path.join(data_dir, str(csv_name)) for csv_name in valid_csv_names]

print(f"Number of samples with missing label data: {null_count}")
# Out:
# Dimensionality of each feature vector is: 49
# Number of samples with missing label data: 54

# %% [markdown]
# ### Generate dataset ###

# %%
def read_data(data_files, label_dict):
    """
    Reads in the data files, binarizes the columns, pads missing values, and normalizes the features.

    Args:
        data_files (list): List of file paths to the data files.
        label_dict (dict): Dictionary mapping file names to (time, event) tuples.

    Returns:
        A tuple containing:
            - rows_tensor (tf.RaggedTensor): A ragged tensor containing the feature vectors for each sample.
            - labels_tensor (tuple): A tuple of two tensors, containing the time and event labels for each sample.
    """
    rows_list = []
    time_list = []
    event_list = []
    empty_count = 0

    # Calculate median values for each feature across all data files
    median_values = compute_median_values(data_files)

    for data_file in data_files:
        # Get the name of the file without the extension
        name = os.path.splitext(os.path.basename(data_file))[0]

        # Skip the file if it is not in the label dictionary
        if name not in label_dict:
            empty_count += 1
            continue

        # Read in the data file
        df = pd.read_csv(data_file)
        

        # Skip the file if it has no rows
        if df.shape[0] < 1:
            empty_count += 1
            print(name)
            continue

        # Binarize the columns and pad missing values
        df = df.iloc[:, 2:]  # Drop the first two columns
        df = binarize_columns(df)
        df = pad_missing_values(df, median_values)

        # Normalize the features
        # df = min_max_normalize_features(df)
    
        # Add the feature vector and labels to the lists
        rows_list.append(df.values)
        time, event = label_dict[name]
        time_list.append(time)
        event_list.append(event)
    
    # Convert the lists to tensors
    rows_tensor = tf.ragged.constant(rows_list, ragged_rank=1, dtype=tf.float32)
    labels_tensor = stack_labels(tf.convert_to_tensor(time_list, dtype=tf.float32),
                                 tf.convert_to_tensor(event_list, dtype=tf.float32))

    print(f"Number of samples: {len(rows_list)}")
    print(f"Number of empty data files: {empty_count}")

    return rows_tensor, labels_tensor

data, labels = read_data(data_files, label_dict)

data = z_score_normalize_ragged_tensor(data)
# Out:
# 2023-05-16 10:29:52.600014: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Number of samples: 1654
# Number of empty data files: 0
# Mean: [-4.4965680e-05  5.5734240e-06 -5.3070180e-06  1.9735680e-05
#  -2.5194002e-05 -9.3263006e-06  1.0113984e-05 -4.9780060e-06
#  -5.3209010e-06 -2.9716795e-05  2.2781544e-05 -1.0131360e-05
#   9.6866052e-06  3.2072548e-05  5.3374402e-05  1.7475038e-05
#   1.6078709e-05 -1.9161647e-05  7.4878062e-07  6.7512759e-05
#  -1.2746840e-05 -3.0244182e-05  4.2329266e-05 -1.4616140e-05
#   3.3741369e-05 -1.1984759e-05  8.5156529e-08 -4.7412617e-05
#   4.5339577e-05  4.9911210e-05 -1.4850494e-06  3.0032786e-06
#   3.4058627e-05  1.7997475e-06  2.2410493e-05  6.9520884e-06
#  -3.3284890e-05  3.9771196e-05  8.6074206e-06 -4.5091103e-05
#  -6.9029061e-06  2.0899532e-05 -2.0842950e-05  6.2503772e-05
#   5.1923698e-06  1.0593353e-04 -4.8191410e-05 -4.3020114e-05
#   2.7419424e-06]
# Standard Deviation: [1.0058852  0.9993391  0.9993592  1.0026546  0.9882494  0.99924344
#  1.0042104  0.9886866  0.9994165  0.98902804 0.9910845  0.99810594
#  1.0031139  1.0016706  1.0060112  0.9851398  1.0049802  0.9916973
#  0.98680294 0.99481964 0.9990781  0.99514663 1.0016357  0.9923684
#  1.0092716  1.0058082  0.9947486  0.9917335  1.0074553  0.98841697
#  0.999998   0.99999815 0.99324006 0.9996833  0.99472576 1.001789
#  0.9917852  1.0082892  1.0060683  0.9941352  0.9908653  1.0066409
#  0.9869019  0.99410945 1.0033078  0.9929745  0.999572   0.99392694
#  1.0020295 ]

# %% [markdown]
# ### Remove subjects with persistent NaNs ###
#
# Some NaNs may remain for subjects (10 samples) that have a single region that also contains NaN features (median imputation doesn't work in this case).

# %%
# After this thread, the dataset size now is reduced from 1655 to 1654
indices = []
for i, subject in enumerate(data):
    if not np.sum(np.isnan(subject)):
        indices.append(i)
data = tf.gather(data, np.array(indices), axis=0)
labels = tf.gather(labels, np.array(indices), axis=0)

# %% [markdown]
# ### Data visualization ###
#
# Visualize the distribution of each features and also a distrubution of the number of time & event labels.

# %%
def visualize_data_distribution(data, labels):
    # Flatten the data and create a DataFrame
    flattened_data = data.flat_values.numpy()
    data_df = pd.DataFrame(flattened_data)
    
    # Visualize the distribution of each feature
    n_features = data_df.shape[1]
    fig, axes = plt.subplots(n_features, 1, figsize=(10, 4 * n_features))

    for i in range(n_features):
        sns.kdeplot(data_df.iloc[:, i], ax=axes[i])
        axes[i].set_title(f"Feature {i+1} Distribution")
        axes[i].set_xlabel(f"Feature {i+1}")
        axes[i].set_ylabel("Density")

    plt.tight_layout()
    plt.show()

    # Visualize the distribution of labels
    labels_df = pd.DataFrame(labels.numpy(), columns=["Time", "Event"])
    
    fig, axes = plt.subplots(1, 2, figsize=(10, 4))

    sns.histplot(labels_df["Time"], kde=True, ax=axes[0], bins=50)
    axes[0].set_title("Time Distribution")
    axes[0].set_xlabel("Time")
    axes[0].set_ylabel("Frequency")

    sns.histplot(labels_df["Event"], discrete=True, ax=axes[1], binwidth=1)
    axes[1].set_title("Event Distribution")
    axes[1].set_xlabel("Event")
    axes[1].set_ylabel("Frequency")
    axes[1].set_xticks([0, 1])

    plt.tight_layout()
    plt.show()

visualize_data_distribution(data, labels)

# %% [markdown]
# ### Attention model architecture ###

# %%
def build_model(D):
    
    # Input layer
    inputs = tf.keras.layers.Input(shape=(None, D), ragged=True)

    # Attention weights
    att = tf.keras.layers.Dense(units=1, activation="relu", name="att")(inputs)

    # Normalize weights to sum to 1
    totals = tf.reduce_sum(att, axis=1, name="att_total")
    normalized = tf.math.divide_no_nan(att, tf.expand_dims(totals, axis=1), name="normalized")

    # Use attention weights to calculate weighted sum of regions
    pooled = tf.linalg.matmul(normalized, inputs, transpose_a=True)

    # Remove the ragged dimension and reshape pooled tensor
    pooled = tf.squeeze(pooled.to_tensor(), axis=1)

    # Apply a linear layer to the pooled vector to generate the time and event risk values
    risk = tf.keras.layers.Dense(units=1, activation="linear", name="risk")(pooled)

    # Build the model
    model = tf.keras.models.Model(inputs=inputs, outputs=[risk, normalized])

    print(f"The input shape of model is: {model.input_shape}")
    print(f"The output shape of model is: {model.output_shape}")

    return model

# Create and compile the model
model_att = build_model(D)
model_att.compile(
    loss={"risk": cox},
    metrics={"risk": HarrellsC()},
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3),
)

ds_data = tf.data.Dataset.from_tensor_slices(data)
ds_labels = tf.data.Dataset.from_tensor_slices(labels)
ds = tf.data.Dataset.zip((ds_data, ds_labels))
ds = ds.batch(64)
for i, batch in enumerate(ds):
    _, l = batch
    events = sum(l[:,1])
    if events < 1.:
        print(f"Warning, 0 events in batch {i}.")

model_att.fit(ds, epochs=200, verbose=1)
# Out:
# The input shape of model is: (None, None, 49)
# The output shape of model is: [(1, 1), (None, None, 1)]
# Epoch 1/200
# /opt/anaconda3/envs/mil/lib/python3.8/site-packages/tensorflow/python/framework/indexed_slices.py:448: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/model_5/input.to_tensor_4/RaggedToTensor/boolean_mask_1/GatherV2:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/model_5/input.to_tensor_4/RaggedToTensor/boolean_mask/GatherV2:0", shape=(None, 49), dtype=float32), dense_shape=Tensor("gradient_tape/model_5/input.to_tensor_4/RaggedToTensor/Shape:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# /opt/anaconda3/envs/mil/lib/python3.8/site-packages/tensorflow/python/framework/indexed_slices.py:448: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/model_5/tf.math.divide_no_nan_4/RaggedTile/Reshape_3:0", shape=(None,), dtype=int64), values=Tensor("gradient_tape/model_5/tf.math.divide_no_nan_4/RaggedTile/Reshape_2:0", shape=(None, 1), dtype=float32), dense_shape=Tensor("gradient_tape/model_5/tf.math.divide_no_nan_4/RaggedTile/Cast:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# 26/26 [==============================] - 5s 13ms/step - loss: 26.9809 - risk_loss: 26.9809 - risk_harrellsc: 0.4871
# Epoch 2/200
# 26/26 [==============================] - 0s 15ms/step - loss: 26.5494 - risk_loss: 26.5494 - risk_harrellsc: 0.4894
# Epoch 3/200
# 26/26 [==============================] - 0s 15ms/step - loss: 26.2406 - risk_loss: 26.2406 - risk_harrellsc: 0.4868
# Epoch 4/200
# 26/26 [==============================] - 0s 13ms/step - loss: 25.9808 - risk_loss: 25.9808 - risk_harrellsc: 0.4869
# Epoch 5/200
# 26/26 [==============================] - 0s 14ms/step - loss: 25.7503 - risk_loss: 25.7503 - risk_harrellsc: 0.4845
# Epoch 6/200
# 26/26 [==============================] - 0s 13ms/step - loss: 25.5441 - risk_loss: 25.5441 - risk_harrellsc: 0.4839
# Epoch 7/200
# 26/26 [==============================] - 0s 15ms/step - loss: 25.3627 - risk_loss: 25.3627 - risk_harrellsc: 0.4833
# Epoch 8/200
# 26/26 [==============================] - 0s 12ms/step - loss: 25.2036 - risk_loss: 25.2036 - risk_harrellsc: 0.4821
# Epoch 9/200
# 26/26 [==============================] - 0s 13ms/step - loss: 25.0627 - risk_loss: 25.0627 - risk_harrellsc: 0.4805
# Epoch 10/200
# 26/26 [==============================] - 0s 13ms/step - loss: 24.9348 - risk_loss: 24.9348 - risk_harrellsc: 0.4843
# Epoch 11/200
# 26/26 [==============================] - 0s 12ms/step - loss: 24.8240 - risk_loss: 24.8240 - risk_harrellsc: 0.4841
# Epoch 12/200
# 26/26 [==============================] - 0s 13ms/step - loss: 24.7295 - risk_loss: 24.7295 - risk_harrellsc: 0.4834
# Epoch 13/200
# 26/26 [==============================] - 0s 15ms/step - loss: 24.6491 - risk_loss: 24.6491 - risk_harrellsc: 0.4825
# Epoch 14/200
# 26/26 [==============================] - 0s 13ms/step - loss: 24.5811 - risk_loss: 24.5811 - risk_harrellsc: 0.4864
# Epoch 15/200
# 26/26 [==============================] - 0s 15ms/step - loss: 24.5227 - risk_loss: 24.5227 - risk_harrellsc: 0.4869
# Epoch 16/200
# 26/26 [==============================] - 0s 18ms/step - loss: 24.4722 - risk_loss: 24.4722 - risk_harrellsc: 0.4854
# Epoch 17/200
# 26/26 [==============================] - 0s 13ms/step - loss: 24.4299 - risk_loss: 24.4299 - risk_harrellsc: 0.4903
# Epoch 18/200
# 26/26 [==============================] - 0s 16ms/step - loss: 24.3931 - risk_loss: 24.3931 - risk_harrellsc: 0.4953
# Epoch 19/200
# 26/26 [==============================] - 0s 15ms/step - loss: 24.3604 - risk_loss: 24.3604 - risk_harrellsc: 0.4938
# Epoch 20/200
# 26/26 [==============================] - 0s 15ms/step - loss: 24.3308 - risk_loss: 24.3308 - risk_harrellsc: 0.4931
# Epoch 21/200
# 26/26 [==============================] - 0s 12ms/step - loss: 24.3038 - risk_loss: 24.3038 - risk_harrellsc: 0.5016
# Epoch 22/200
# 26/26 [==============================] - 0s 14ms/step - loss: 24.2787 - risk_loss: 24.2787 - risk_harrellsc: 0.5021
# Epoch 23/200
# 26/26 [==============================] - 0s 13ms/step - loss: 24.2563 - risk_loss: 24.2563 - risk_harrellsc: 0.5005
# Epoch 24/200
# 26/26 [==============================] - 0s 13ms/step - loss: 24.2352 - risk_loss: 24.2352 - risk_harrellsc: 0.4995
# Epoch 25/200
# 26/26 [==============================] - 0s 13ms/step - loss: 24.2147 - risk_loss: 24.2147 - risk_harrellsc: 0.4978
# Epoch 26/200
# 26/26 [==============================] - 0s 16ms/step - loss: 24.1953 - risk_loss: 24.1953 - risk_harrellsc: 0.4976
# Epoch 27/200
# 26/26 [==============================] - 0s 14ms/step - loss: 24.1780 - risk_loss: 24.1780 - risk_harrellsc: 0.4948
# Epoch 28/200
# 26/26 [==============================] - 0s 14ms/step - loss: 24.1617 - risk_loss: 24.1617 - risk_harrellsc: 0.4934
# Epoch 29/200
# 26/26 [==============================] - 0s 17ms/step - loss: 24.1465 - risk_loss: 24.1465 - risk_harrellsc: 0.5014
# Epoch 30/200
# 26/26 [==============================] - 0s 13ms/step - loss: 24.1322 - risk_loss: 24.1322 - risk_harrellsc: 0.5069
# Epoch 31/200
# 26/26 [==============================] - 0s 14ms/step - loss: 24.1185 - risk_loss: 24.1185 - risk_harrellsc: 0.5032
# Epoch 32/200
# 26/26 [==============================] - 0s 15ms/step - loss: 24.1056 - risk_loss: 24.1056 - risk_harrellsc: 0.5151
# Epoch 33/200
# 26/26 [==============================] - 0s 15ms/step - loss: 24.0936 - risk_loss: 24.0936 - risk_harrellsc: 0.5126
# Epoch 34/200
# 26/26 [==============================] - 0s 13ms/step - loss: 24.0821 - risk_loss: 24.0821 - risk_harrellsc: 0.5155
# Epoch 35/200
# 26/26 [==============================] - 0s 13ms/step - loss: 24.0714 - risk_loss: 24.0714 - risk_harrellsc: 0.5155
# Epoch 36/200
# 26/26 [==============================] - 0s 17ms/step - loss: 24.0603 - risk_loss: 24.0603 - risk_harrellsc: 0.5210
# Epoch 37/200
# 26/26 [==============================] - 0s 14ms/step - loss: 24.0498 - risk_loss: 24.0498 - risk_harrellsc: 0.5275
# Epoch 38/200
# 26/26 [==============================] - 0s 16ms/step - loss: 24.0390 - risk_loss: 24.0390 - risk_harrellsc: 0.5279
# Epoch 39/200
# 26/26 [==============================] - 0s 17ms/step - loss: 24.0289 - risk_loss: 24.0289 - risk_harrellsc: 0.5291
# Epoch 40/200
# 26/26 [==============================] - 0s 13ms/step - loss: 24.0184 - risk_loss: 24.0184 - risk_harrellsc: 0.5271
# Epoch 41/200
# 26/26 [==============================] - 0s 14ms/step - loss: 24.0092 - risk_loss: 24.0092 - risk_harrellsc: 0.5261
# Epoch 42/200
# 26/26 [==============================] - 0s 14ms/step - loss: 23.9997 - risk_loss: 23.9997 - risk_harrellsc: 0.5317
# Epoch 43/200
# 26/26 [==============================] - 0s 18ms/step - loss: 23.9897 - risk_loss: 23.9897 - risk_harrellsc: 0.5309
# Epoch 44/200
# 26/26 [==============================] - 0s 15ms/step - loss: 23.9802 - risk_loss: 23.9802 - risk_harrellsc: 0.5294
# Epoch 45/200
# 26/26 [==============================] - 0s 15ms/step - loss: 23.9731 - risk_loss: 23.9731 - risk_harrellsc: 0.5290
# Epoch 46/200
# 26/26 [==============================] - 1s 20ms/step - loss: 23.9675 - risk_loss: 23.9675 - risk_harrellsc: 0.5282
# Epoch 47/200
# 26/26 [==============================] - 0s 13ms/step - loss: 23.9627 - risk_loss: 23.9627 - risk_harrellsc: 0.5280
# Epoch 48/200
# 26/26 [==============================] - 0s 12ms/step - loss: 23.9571 - risk_loss: 23.9571 - risk_harrellsc: 0.5297
# Epoch 49/200
# 26/26 [==============================] - 0s 14ms/step - loss: 23.9473 - risk_loss: 23.9473 - risk_harrellsc: 0.5313
# Epoch 50/200
# 26/26 [==============================] - 0s 12ms/step - loss: 23.9412 - risk_loss: 23.9412 - risk_harrellsc: 0.5323
# Epoch 51/200
# 26/26 [==============================] - 0s 12ms/step - loss: 23.9357 - risk_loss: 23.9357 - risk_harrellsc: 0.5369
# Epoch 52/200
# 26/26 [==============================] - 0s 11ms/step - loss: 23.9308 - risk_loss: 23.9308 - risk_harrellsc: 0.5372
# Epoch 53/200
# 26/26 [==============================] - 0s 15ms/step - loss: 23.9260 - risk_loss: 23.9260 - risk_harrellsc: 0.5366
# Epoch 54/200
# 26/26 [==============================] - 0s 12ms/step - loss: 23.9250 - risk_loss: 23.9250 - risk_harrellsc: 0.5368
# Epoch 55/200
# 26/26 [==============================] - 0s 12ms/step - loss: 23.9188 - risk_loss: 23.9188 - risk_harrellsc: 0.5406
# Epoch 56/200
# 26/26 [==============================] - 0s 15ms/step - loss: 23.9131 - risk_loss: 23.9131 - risk_harrellsc: 0.5417
# Epoch 57/200
# 26/26 [==============================] - 0s 12ms/step - loss: 23.9076 - risk_loss: 23.9076 - risk_harrellsc: 0.5401
# Epoch 58/200
# 26/26 [==============================] - 0s 13ms/step - loss: 23.9026 - risk_loss: 23.9026 - risk_harrellsc: 0.5397
# Epoch 59/200
# 26/26 [==============================] - 0s 12ms/step - loss: 23.8982 - risk_loss: 23.8982 - risk_harrellsc: 0.5388
# Epoch 60/200
# 26/26 [==============================] - 0s 16ms/step - loss: 23.8935 - risk_loss: 23.8935 - risk_harrellsc: 0.5369
# Epoch 61/200
# 26/26 [==============================] - 0s 11ms/step - loss: 23.8889 - risk_loss: 23.8889 - risk_harrellsc: 0.5369
# Epoch 62/200
# 26/26 [==============================] - 0s 12ms/step - loss: 23.8844 - risk_loss: 23.8844 - risk_harrellsc: 0.5373
# Epoch 63/200
# 26/26 [==============================] - 0s 13ms/step - loss: 23.8791 - risk_loss: 23.8791 - risk_harrellsc: 0.5381
# Epoch 64/200
# 26/26 [==============================] - 0s 14ms/step - loss: 23.8714 - risk_loss: 23.8714 - risk_harrellsc: 0.5443
# Epoch 65/200
# 26/26 [==============================] - 0s 11ms/step - loss: 23.8673 - risk_loss: 23.8673 - risk_harrellsc: 0.5408
# Epoch 66/200
# 26/26 [==============================] - 0s 13ms/step - loss: 23.8630 - risk_loss: 23.8630 - risk_harrellsc: 0.5411
# Epoch 67/200
# 26/26 [==============================] - 0s 12ms/step - loss: 23.8593 - risk_loss: 23.8593 - risk_harrellsc: 0.5409
# Epoch 68/200
# 26/26 [==============================] - 1s 21ms/step - loss: 23.8548 - risk_loss: 23.8548 - risk_harrellsc: 0.5411
# Epoch 69/200
# 26/26 [==============================] - 1s 16ms/step - loss: 23.8504 - risk_loss: 23.8504 - risk_harrellsc: 0.5411
# Epoch 70/200
# 26/26 [==============================] - 0s 12ms/step - loss: 23.8461 - risk_loss: 23.8461 - risk_harrellsc: 0.5418
# Epoch 71/200
# 26/26 [==============================] - 0s 17ms/step - loss: 23.8409 - risk_loss: 23.8409 - risk_harrellsc: 0.5421
# Epoch 72/200
# 26/26 [==============================] - 0s 15ms/step - loss: 23.8360 - risk_loss: 23.8360 - risk_harrellsc: 0.5428
# Epoch 73/200
# 26/26 [==============================] - 0s 12ms/step - loss: 23.8321 - risk_loss: 23.8321 - risk_harrellsc: 0.5428
# Epoch 74/200
# 26/26 [==============================] - 0s 12ms/step - loss: 23.8276 - risk_loss: 23.8276 - risk_harrellsc: 0.5427
# Epoch 75/200
# 26/26 [==============================] - 0s 12ms/step - loss: 23.8231 - risk_loss: 23.8231 - risk_harrellsc: 0.5421
# Epoch 76/200
# 26/26 [==============================] - 0s 14ms/step - loss: 23.8182 - risk_loss: 23.8182 - risk_harrellsc: 0.5417
# Epoch 77/200
# 26/26 [==============================] - 0s 17ms/step - loss: 23.8134 - risk_loss: 23.8134 - risk_harrellsc: 0.5434
# Epoch 78/200
# 26/26 [==============================] - 0s 17ms/step - loss: 23.8093 - risk_loss: 23.8093 - risk_harrellsc: 0.5433
# Epoch 79/200
# 26/26 [==============================] - 0s 13ms/step - loss: 23.8047 - risk_loss: 23.8047 - risk_harrellsc: 0.5424
# Epoch 80/200
# 26/26 [==============================] - 0s 12ms/step - loss: 23.8000 - risk_loss: 23.8000 - risk_harrellsc: 0.5427
# Epoch 81/200
# 26/26 [==============================] - 0s 15ms/step - loss: 23.7946 - risk_loss: 23.7946 - risk_harrellsc: 0.5427
# Epoch 82/200
# 26/26 [==============================] - 0s 16ms/step - loss: 23.7966 - risk_loss: 23.7966 - risk_harrellsc: 0.5440
# Epoch 83/200
# 26/26 [==============================] - 0s 11ms/step - loss: 23.8170 - risk_loss: 23.8170 - risk_harrellsc: 0.5351
# Epoch 84/200
# 26/26 [==============================] - 0s 13ms/step - loss: 23.8114 - risk_loss: 23.8114 - risk_harrellsc: 0.5353
# Epoch 85/200
# 26/26 [==============================] - 0s 16ms/step - loss: 23.8054 - risk_loss: 23.8054 - risk_harrellsc: 0.5407
# Epoch 86/200
# 26/26 [==============================] - 0s 19ms/step - loss: 23.8013 - risk_loss: 23.8013 - risk_harrellsc: 0.5415
# Epoch 87/200
# 26/26 [==============================] - 0s 14ms/step - loss: 23.7961 - risk_loss: 23.7961 - risk_harrellsc: 0.5419
# Epoch 88/200
# 26/26 [==============================] - 0s 15ms/step - loss: 23.7742 - risk_loss: 23.7742 - risk_harrellsc: 0.5511
# Epoch 89/200
# 26/26 [==============================] - 0s 19ms/step - loss: 23.7666 - risk_loss: 23.7666 - risk_harrellsc: 0.5480
# Epoch 90/200
# 26/26 [==============================] - 0s 12ms/step - loss: 23.7633 - risk_loss: 23.7633 - risk_harrellsc: 0.5485
# Epoch 91/200
# 26/26 [==============================] - 0s 12ms/step - loss: 23.7601 - risk_loss: 23.7601 - risk_harrellsc: 0.5500
# Epoch 92/200
# 26/26 [==============================] - 0s 13ms/step - loss: 23.7481 - risk_loss: 23.7481 - risk_harrellsc: 0.5527
# Epoch 93/200
# 26/26 [==============================] - 0s 14ms/step - loss: 23.7392 - risk_loss: 23.7392 - risk_harrellsc: 0.5509
# Epoch 94/200
# 26/26 [==============================] - 0s 12ms/step - loss: 23.7354 - risk_loss: 23.7354 - risk_harrellsc: 0.5513
# Epoch 95/200
# 26/26 [==============================] - 0s 13ms/step - loss: 23.7312 - risk_loss: 23.7312 - risk_harrellsc: 0.5534
# Epoch 96/200
# 26/26 [==============================] - 0s 13ms/step - loss: 23.7267 - risk_loss: 23.7267 - risk_harrellsc: 0.5534
# Epoch 97/200
# 26/26 [==============================] - 0s 16ms/step - loss: 23.7223 - risk_loss: 23.7223 - risk_harrellsc: 0.5535
# Epoch 98/200
# 26/26 [==============================] - 0s 13ms/step - loss: 23.7176 - risk_loss: 23.7176 - risk_harrellsc: 0.5544
# Epoch 99/200
# 26/26 [==============================] - 0s 13ms/step - loss: 23.7126 - risk_loss: 23.7126 - risk_harrellsc: 0.5543
# Epoch 100/200
# 26/26 [==============================] - 0s 12ms/step - loss: 23.7108 - risk_loss: 23.7108 - risk_harrellsc: 0.5485
# Epoch 101/200
# 26/26 [==============================] - 0s 15ms/step - loss: 23.7027 - risk_loss: 23.7027 - risk_harrellsc: 0.5553
# Epoch 102/200
# 26/26 [==============================] - 0s 12ms/step - loss: 23.7021 - risk_loss: 23.7021 - risk_harrellsc: 0.5547
# Epoch 103/200
# 26/26 [==============================] - 0s 13ms/step - loss: 23.6944 - risk_loss: 23.6944 - risk_harrellsc: 0.5560
# Epoch 104/200
# 26/26 [==============================] - 1s 20ms/step - loss: 23.6904 - risk_loss: 23.6904 - risk_harrellsc: 0.5549
# Epoch 105/200
# 26/26 [==============================] - 0s 16ms/step - loss: 23.6843 - risk_loss: 23.6843 - risk_harrellsc: 0.5556
# Epoch 106/200
# 26/26 [==============================] - 0s 17ms/step - loss: 23.6774 - risk_loss: 23.6774 - risk_harrellsc: 0.5563
# Epoch 107/200
# 26/26 [==============================] - 0s 18ms/step - loss: 23.6695 - risk_loss: 23.6695 - risk_harrellsc: 0.5525
# Epoch 108/200
# 26/26 [==============================] - 0s 13ms/step - loss: 23.6974 - risk_loss: 23.6974 - risk_harrellsc: 0.5508
# Epoch 109/200
# 26/26 [==============================] - 0s 13ms/step - loss: 23.7379 - risk_loss: 23.7379 - risk_harrellsc: 0.5497
# Epoch 110/200
# 26/26 [==============================] - 0s 12ms/step - loss: 23.6768 - risk_loss: 23.6768 - risk_harrellsc: 0.5484
# Epoch 111/200
# 26/26 [==============================] - 0s 18ms/step - loss: 23.6649 - risk_loss: 23.6649 - risk_harrellsc: 0.5514
# Epoch 112/200
# 26/26 [==============================] - 0s 19ms/step - loss: 23.6632 - risk_loss: 23.6632 - risk_harrellsc: 0.5521
# Epoch 113/200
# 26/26 [==============================] - 0s 14ms/step - loss: 23.6487 - risk_loss: 23.6487 - risk_harrellsc: 0.5486
# Epoch 114/200
# 26/26 [==============================] - 0s 13ms/step - loss: 23.6484 - risk_loss: 23.6484 - risk_harrellsc: 0.5509
# Epoch 115/200
# 26/26 [==============================] - 0s 17ms/step - loss: 23.6833 - risk_loss: 23.6833 - risk_harrellsc: 0.5447
# Epoch 116/200
# 26/26 [==============================] - 0s 15ms/step - loss: 23.6804 - risk_loss: 23.6804 - risk_harrellsc: 0.5457
# Epoch 117/200
# 26/26 [==============================] - 0s 12ms/step - loss: 23.6690 - risk_loss: 23.6690 - risk_harrellsc: 0.5387
# Epoch 118/200
# 26/26 [==============================] - 0s 14ms/step - loss: 23.6507 - risk_loss: 23.6507 - risk_harrellsc: 0.5376
# Epoch 119/200
# 26/26 [==============================] - 0s 14ms/step - loss: 23.6474 - risk_loss: 23.6474 - risk_harrellsc: 0.5389
# Epoch 120/200
# 26/26 [==============================] - 0s 18ms/step - loss: 23.6358 - risk_loss: 23.6358 - risk_harrellsc: 0.5439
# Epoch 121/200
# 26/26 [==============================] - 0s 15ms/step - loss: 23.6358 - risk_loss: 23.6358 - risk_harrellsc: 0.5493
# Epoch 122/200
# 26/26 [==============================] - 0s 14ms/step - loss: 23.6254 - risk_loss: 23.6254 - risk_harrellsc: 0.5564
# Epoch 123/200
# 26/26 [==============================] - 0s 12ms/step - loss: 23.6232 - risk_loss: 23.6232 - risk_harrellsc: 0.5493
# Epoch 124/200
# 26/26 [==============================] - 0s 12ms/step - loss: 23.6110 - risk_loss: 23.6110 - risk_harrellsc: 0.5496
# Epoch 125/200
# 26/26 [==============================] - 0s 17ms/step - loss: 23.5960 - risk_loss: 23.5960 - risk_harrellsc: 0.5522
# Epoch 126/200
# 26/26 [==============================] - 0s 14ms/step - loss: 23.5932 - risk_loss: 23.5932 - risk_harrellsc: 0.5499
# Epoch 127/200
# 26/26 [==============================] - 0s 15ms/step - loss: 23.5869 - risk_loss: 23.5869 - risk_harrellsc: 0.5538
# Epoch 128/200
# 26/26 [==============================] - 1s 28ms/step - loss: 23.6110 - risk_loss: 23.6110 - risk_harrellsc: 0.5595
# Epoch 129/200
# 26/26 [==============================] - 1s 20ms/step - loss: 23.5766 - risk_loss: 23.5766 - risk_harrellsc: 0.5558
# Epoch 130/200
# 26/26 [==============================] - 0s 18ms/step - loss: 23.5527 - risk_loss: 23.5527 - risk_harrellsc: 0.5506
# Epoch 131/200
# 26/26 [==============================] - 0s 17ms/step - loss: 23.5838 - risk_loss: 23.5838 - risk_harrellsc: 0.5542
# Epoch 132/200
# 26/26 [==============================] - 1s 22ms/step - loss: 23.6245 - risk_loss: 23.6245 - risk_harrellsc: 0.5596
# Epoch 133/200
# 26/26 [==============================] - 1s 20ms/step - loss: 23.6474 - risk_loss: 23.6474 - risk_harrellsc: 0.5519
# Epoch 134/200
# 26/26 [==============================] - 1s 27ms/step - loss: 23.6167 - risk_loss: 23.6167 - risk_harrellsc: 0.5555
# Epoch 135/200
# 26/26 [==============================] - 1s 26ms/step - loss: 23.5774 - risk_loss: 23.5774 - risk_harrellsc: 0.5569
# Epoch 136/200
# 26/26 [==============================] - 1s 30ms/step - loss: 23.5553 - risk_loss: 23.5553 - risk_harrellsc: 0.5616
# Epoch 137/200
# 26/26 [==============================] - 0s 14ms/step - loss: 23.5372 - risk_loss: 23.5372 - risk_harrellsc: 0.5612
# Epoch 138/200
# 26/26 [==============================] - 0s 11ms/step - loss: 23.5090 - risk_loss: 23.5090 - risk_harrellsc: 0.5538
# Epoch 139/200
# 26/26 [==============================] - 0s 16ms/step - loss: 23.5371 - risk_loss: 23.5371 - risk_harrellsc: 0.5523
# Epoch 140/200
# 26/26 [==============================] - 0s 12ms/step - loss: 23.4942 - risk_loss: 23.4942 - risk_harrellsc: 0.5576
# Epoch 141/200
# 26/26 [==============================] - 0s 13ms/step - loss: 23.5220 - risk_loss: 23.5220 - risk_harrellsc: 0.5544
# Epoch 142/200
# 26/26 [==============================] - 0s 15ms/step - loss: 23.5093 - risk_loss: 23.5093 - risk_harrellsc: 0.5569
# Epoch 143/200
# 26/26 [==============================] - 0s 15ms/step - loss: 23.4658 - risk_loss: 23.4658 - risk_harrellsc: 0.5595
# Epoch 144/200
# 26/26 [==============================] - 0s 13ms/step - loss: 23.4589 - risk_loss: 23.4589 - risk_harrellsc: 0.5580
# Epoch 145/200
# 26/26 [==============================] - 0s 11ms/step - loss: 23.4864 - risk_loss: 23.4864 - risk_harrellsc: 0.5601
# Epoch 146/200
# 26/26 [==============================] - 0s 19ms/step - loss: 23.4775 - risk_loss: 23.4775 - risk_harrellsc: 0.5574
# Epoch 147/200
# 26/26 [==============================] - 0s 16ms/step - loss: 23.4367 - risk_loss: 23.4367 - risk_harrellsc: 0.5574
# Epoch 148/200
# 26/26 [==============================] - 0s 15ms/step - loss: 23.4719 - risk_loss: 23.4719 - risk_harrellsc: 0.5569
# Epoch 149/200
# 26/26 [==============================] - 0s 12ms/step - loss: 23.4687 - risk_loss: 23.4687 - risk_harrellsc: 0.5571
# Epoch 150/200
# 26/26 [==============================] - 0s 12ms/step - loss: 23.4208 - risk_loss: 23.4208 - risk_harrellsc: 0.5644
# Epoch 151/200
# 26/26 [==============================] - 0s 12ms/step - loss: 23.4177 - risk_loss: 23.4177 - risk_harrellsc: 0.5640
# Epoch 152/200
# 26/26 [==============================] - 0s 14ms/step - loss: 23.4416 - risk_loss: 23.4416 - risk_harrellsc: 0.5704
# Epoch 153/200
# 26/26 [==============================] - 0s 14ms/step - loss: 23.4680 - risk_loss: 23.4680 - risk_harrellsc: 0.5598
# Epoch 154/200
# 26/26 [==============================] - 0s 12ms/step - loss: 23.4758 - risk_loss: 23.4758 - risk_harrellsc: 0.5616
# Epoch 155/200
# 26/26 [==============================] - 0s 15ms/step - loss: 23.5166 - risk_loss: 23.5166 - risk_harrellsc: 0.5683
# Epoch 156/200
# 26/26 [==============================] - 0s 15ms/step - loss: 23.5078 - risk_loss: 23.5078 - risk_harrellsc: 0.5602
# Epoch 157/200
# 26/26 [==============================] - 0s 13ms/step - loss: 23.4532 - risk_loss: 23.4532 - risk_harrellsc: 0.5641
# Epoch 158/200
# 26/26 [==============================] - 0s 13ms/step - loss: 23.4245 - risk_loss: 23.4245 - risk_harrellsc: 0.5563
# Epoch 159/200
# 26/26 [==============================] - 0s 17ms/step - loss: 23.4082 - risk_loss: 23.4082 - risk_harrellsc: 0.5618
# Epoch 160/200
# 26/26 [==============================] - 0s 13ms/step - loss: 23.3886 - risk_loss: 23.3886 - risk_harrellsc: 0.5632
# Epoch 161/200
# 26/26 [==============================] - 0s 12ms/step - loss: 23.3845 - risk_loss: 23.3845 - risk_harrellsc: 0.5632
# Epoch 162/200
# 26/26 [==============================] - 0s 16ms/step - loss: 23.3942 - risk_loss: 23.3942 - risk_harrellsc: 0.5622
# Epoch 163/200
# 26/26 [==============================] - 0s 15ms/step - loss: 23.4172 - risk_loss: 23.4172 - risk_harrellsc: 0.5634
# Epoch 164/200
# 26/26 [==============================] - 0s 13ms/step - loss: 23.4004 - risk_loss: 23.4004 - risk_harrellsc: 0.5651
# Epoch 165/200
# 26/26 [==============================] - 0s 15ms/step - loss: 23.3914 - risk_loss: 23.3914 - risk_harrellsc: 0.5684
# Epoch 166/200
# 26/26 [==============================] - 0s 12ms/step - loss: 23.3451 - risk_loss: 23.3451 - risk_harrellsc: 0.5714
# Epoch 167/200
# 26/26 [==============================] - 0s 12ms/step - loss: 23.3396 - risk_loss: 23.3396 - risk_harrellsc: 0.5687
# Epoch 168/200
# 26/26 [==============================] - 0s 12ms/step - loss: 23.3343 - risk_loss: 23.3343 - risk_harrellsc: 0.5647
# Epoch 169/200
# 26/26 [==============================] - 0s 15ms/step - loss: 23.3288 - risk_loss: 23.3288 - risk_harrellsc: 0.5656
# Epoch 170/200
# 26/26 [==============================] - 0s 13ms/step - loss: 23.3654 - risk_loss: 23.3654 - risk_harrellsc: 0.5651
# Epoch 171/200
# 26/26 [==============================] - 0s 12ms/step - loss: 23.3520 - risk_loss: 23.3520 - risk_harrellsc: 0.5672
# Epoch 172/200
# 26/26 [==============================] - 0s 12ms/step - loss: 23.3124 - risk_loss: 23.3124 - risk_harrellsc: 0.5711
# Epoch 173/200
# 26/26 [==============================] - 0s 16ms/step - loss: 23.3108 - risk_loss: 23.3108 - risk_harrellsc: 0.5663
# Epoch 174/200
# 26/26 [==============================] - 0s 12ms/step - loss: 23.3050 - risk_loss: 23.3050 - risk_harrellsc: 0.5691
# Epoch 175/200
# 26/26 [==============================] - 0s 13ms/step - loss: 23.3003 - risk_loss: 23.3003 - risk_harrellsc: 0.5663
# Epoch 176/200
# 26/26 [==============================] - 0s 16ms/step - loss: 23.2919 - risk_loss: 23.2919 - risk_harrellsc: 0.5646
# Epoch 177/200
# 26/26 [==============================] - 0s 12ms/step - loss: 23.2953 - risk_loss: 23.2953 - risk_harrellsc: 0.5646
# Epoch 178/200
# 26/26 [==============================] - 0s 11ms/step - loss: 23.2824 - risk_loss: 23.2824 - risk_harrellsc: 0.5693
# Epoch 179/200
# 26/26 [==============================] - 0s 15ms/step - loss: 23.2802 - risk_loss: 23.2802 - risk_harrellsc: 0.5653
# Epoch 180/200
# 26/26 [==============================] - 0s 12ms/step - loss: 23.2825 - risk_loss: 23.2825 - risk_harrellsc: 0.5656
# Epoch 181/200
# 26/26 [==============================] - 0s 12ms/step - loss: 23.3085 - risk_loss: 23.3085 - risk_harrellsc: 0.5663
# Epoch 182/200
# 26/26 [==============================] - 0s 15ms/step - loss: 23.2629 - risk_loss: 23.2629 - risk_harrellsc: 0.5625
# Epoch 183/200
# 26/26 [==============================] - 0s 12ms/step - loss: 23.2600 - risk_loss: 23.2600 - risk_harrellsc: 0.5661
# Epoch 184/200
# 26/26 [==============================] - 0s 13ms/step - loss: 23.2630 - risk_loss: 23.2630 - risk_harrellsc: 0.5664
# Epoch 185/200
# 26/26 [==============================] - 0s 15ms/step - loss: 23.2504 - risk_loss: 23.2504 - risk_harrellsc: 0.5676
# Epoch 186/200
# 26/26 [==============================] - 0s 15ms/step - loss: 23.2720 - risk_loss: 23.2720 - risk_harrellsc: 0.5737
# Epoch 187/200
# 26/26 [==============================] - 0s 14ms/step - loss: 23.3643 - risk_loss: 23.3643 - risk_harrellsc: 0.5632
# Epoch 188/200
# 26/26 [==============================] - 0s 13ms/step - loss: 23.2984 - risk_loss: 23.2984 - risk_harrellsc: 0.5541
# Epoch 189/200
# 26/26 [==============================] - 0s 14ms/step - loss: 23.2632 - risk_loss: 23.2632 - risk_harrellsc: 0.5589
# Epoch 190/200
# 26/26 [==============================] - 0s 14ms/step - loss: 23.2541 - risk_loss: 23.2541 - risk_harrellsc: 0.5628
# Epoch 191/200
# 26/26 [==============================] - 0s 12ms/step - loss: 23.2481 - risk_loss: 23.2481 - risk_harrellsc: 0.5624
# Epoch 192/200
# 26/26 [==============================] - 0s 14ms/step - loss: 23.2368 - risk_loss: 23.2368 - risk_harrellsc: 0.5626
# Epoch 193/200
# 26/26 [==============================] - 0s 12ms/step - loss: 23.2409 - risk_loss: 23.2409 - risk_harrellsc: 0.5694
# Epoch 194/200
# 26/26 [==============================] - 0s 13ms/step - loss: 23.2268 - risk_loss: 23.2268 - risk_harrellsc: 0.5632
# Epoch 195/200
# 26/26 [==============================] - 0s 13ms/step - loss: 23.2329 - risk_loss: 23.2329 - risk_harrellsc: 0.5641
# Epoch 196/200
# 26/26 [==============================] - 0s 13ms/step - loss: 23.2207 - risk_loss: 23.2207 - risk_harrellsc: 0.5634
# Epoch 197/200
# 26/26 [==============================] - 0s 12ms/step - loss: 23.2215 - risk_loss: 23.2215 - risk_harrellsc: 0.5639
# Epoch 198/200
# 26/26 [==============================] - 0s 14ms/step - loss: 23.2173 - risk_loss: 23.2173 - risk_harrellsc: 0.5639
# Epoch 199/200
# 26/26 [==============================] - 0s 15ms/step - loss: 23.2113 - risk_loss: 23.2113 - risk_harrellsc: 0.5639
# Epoch 200/200
# 26/26 [==============================] - 0s 13ms/step - loss: 23.2113 - risk_loss: 23.2113 - risk_harrellsc: 0.5656

# %% [markdown]
# ### Averaging model architecture ###

# %%
def build_model(D):
    
    # Input layer
    inputs = tf.keras.layers.Input(shape=(None, D), ragged=True)

    # Average feature vectors along the ragged dimension
    averaged = tf.reduce_mean(inputs, axis=1)

    # Apply a linear layer to the averaged vector to generate the time and event risk values
    risk = tf.keras.layers.Dense(units=1, activation="linear", name="risk")(averaged)

    # Build the model
    model = tf.keras.models.Model(inputs=inputs, outputs=risk)

    print(f"The input shape of model is: {model.input_shape}")
    print(f"The output shape of model is: {model.output_shape}")

    return model

# Create and compile the model
model_avg = build_model(D)
model_avg.compile(
    loss={"risk": efron},
    metrics={"risk": HarrellsC()},
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3),
)

ds_data = tf.data.Dataset.from_tensor_slices(data)
ds_labels = tf.data.Dataset.from_tensor_slices(labels)
ds = tf.data.Dataset.zip((ds_data, ds_labels))
ds = ds.batch(64)
for i, batch in enumerate(ds):
    _, l = batch
    events = sum(l[:,1])
    if events < 1.:
        print(f"Warning, 0 events in batch {i}.")

model_avg.fit(ds, epochs=100, verbose=1)
# Out:
# The input shape of model is: (None, None, 49)
# The output shape of model is: (None, 1)
# Epoch 1/100
# 26/26 [==============================] - 4s 12ms/step - loss: 24.6203 - harrellsc: 0.4001
# Epoch 2/100
# 26/26 [==============================] - 0s 8ms/step - loss: 24.3684 - harrellsc: 0.4057
# Epoch 3/100
# 26/26 [==============================] - 0s 9ms/step - loss: 24.3233 - harrellsc: 0.4108
# Epoch 4/100
# 26/26 [==============================] - 0s 8ms/step - loss: 24.2939 - harrellsc: 0.4097
# Epoch 5/100
# 26/26 [==============================] - 0s 8ms/step - loss: 24.2690 - harrellsc: 0.4049
# Epoch 6/100
# 26/26 [==============================] - 0s 9ms/step - loss: 24.2470 - harrellsc: 0.4063
# Epoch 7/100
# 26/26 [==============================] - 0s 12ms/step - loss: 24.2277 - harrellsc: 0.4079
# Epoch 8/100
# 26/26 [==============================] - 0s 11ms/step - loss: 24.2110 - harrellsc: 0.4224
# Epoch 9/100
# 26/26 [==============================] - 0s 9ms/step - loss: 24.1966 - harrellsc: 0.4168
# Epoch 10/100
# 26/26 [==============================] - 0s 8ms/step - loss: 24.1840 - harrellsc: 0.4223
# Epoch 11/100
# 26/26 [==============================] - 0s 9ms/step - loss: 24.1730 - harrellsc: 0.4189
# Epoch 12/100
# 26/26 [==============================] - 0s 11ms/step - loss: 24.1633 - harrellsc: 0.4191
# Epoch 13/100
# 26/26 [==============================] - 0s 10ms/step - loss: 24.1547 - harrellsc: 0.4163
# Epoch 14/100
# 26/26 [==============================] - 0s 10ms/step - loss: 24.1470 - harrellsc: 0.4268
# Epoch 15/100
# 26/26 [==============================] - 0s 11ms/step - loss: 24.1401 - harrellsc: 0.4202
# Epoch 16/100
# 26/26 [==============================] - 0s 9ms/step - loss: 24.1338 - harrellsc: 0.4203
# Epoch 17/100
# 26/26 [==============================] - 0s 8ms/step - loss: 24.1281 - harrellsc: 0.4249
# Epoch 18/100
# 26/26 [==============================] - 0s 8ms/step - loss: 24.1228 - harrellsc: 0.4378
# Epoch 19/100
# 26/26 [==============================] - 0s 9ms/step - loss: 24.1180 - harrellsc: 0.4323
# Epoch 20/100
# 26/26 [==============================] - 0s 12ms/step - loss: 24.1135 - harrellsc: 0.4324
# Epoch 21/100
# 26/26 [==============================] - 0s 9ms/step - loss: 24.1093 - harrellsc: 0.4394
# Epoch 22/100
# 26/26 [==============================] - 0s 9ms/step - loss: 24.1053 - harrellsc: 0.4384
# Epoch 23/100
# 26/26 [==============================] - 0s 9ms/step - loss: 24.1016 - harrellsc: 0.4378
# Epoch 24/100
# 26/26 [==============================] - 0s 11ms/step - loss: 24.0981 - harrellsc: 0.4411
# Epoch 25/100
# 26/26 [==============================] - 0s 9ms/step - loss: 24.0948 - harrellsc: 0.4357
# Epoch 26/100
# 26/26 [==============================] - 0s 8ms/step - loss: 24.0916 - harrellsc: 0.4344
# Epoch 27/100
# 26/26 [==============================] - 0s 8ms/step - loss: 24.0886 - harrellsc: 0.4392
# Epoch 28/100
# 26/26 [==============================] - 0s 8ms/step - loss: 24.0857 - harrellsc: 0.4427
# Epoch 29/100
# 26/26 [==============================] - 0s 11ms/step - loss: 24.0829 - harrellsc: 0.4420
# Epoch 30/100
# 26/26 [==============================] - 0s 9ms/step - loss: 24.0802 - harrellsc: 0.4364
# Epoch 31/100
# 26/26 [==============================] - 0s 8ms/step - loss: 24.0776 - harrellsc: 0.4393
# Epoch 32/100
# 26/26 [==============================] - 0s 10ms/step - loss: 24.0752 - harrellsc: 0.4413
# Epoch 33/100
# 26/26 [==============================] - 0s 9ms/step - loss: 24.0728 - harrellsc: 0.4429
# Epoch 34/100
# 26/26 [==============================] - 0s 9ms/step - loss: 24.0704 - harrellsc: 0.4409
# Epoch 35/100
# 26/26 [==============================] - 0s 8ms/step - loss: 24.0682 - harrellsc: 0.4424
# Epoch 36/100
# 26/26 [==============================] - 0s 8ms/step - loss: 24.0660 - harrellsc: 0.4449
# Epoch 37/100
# 26/26 [==============================] - 0s 8ms/step - loss: 24.0639 - harrellsc: 0.4444
# Epoch 38/100
# 26/26 [==============================] - 0s 8ms/step - loss: 24.0618 - harrellsc: 0.4455
# Epoch 39/100
# 26/26 [==============================] - 0s 11ms/step - loss: 24.0598 - harrellsc: 0.4439
# Epoch 40/100
# 26/26 [==============================] - 0s 10ms/step - loss: 24.0578 - harrellsc: 0.4499
# Epoch 41/100
# 26/26 [==============================] - 0s 9ms/step - loss: 24.0559 - harrellsc: 0.4501
# Epoch 42/100
# 26/26 [==============================] - 0s 9ms/step - loss: 24.0540 - harrellsc: 0.4431
# Epoch 43/100
# 26/26 [==============================] - 0s 16ms/step - loss: 24.0522 - harrellsc: 0.4474
# Epoch 44/100
# 26/26 [==============================] - 0s 15ms/step - loss: 24.0504 - harrellsc: 0.4477
# Epoch 45/100
# 26/26 [==============================] - 0s 11ms/step - loss: 24.0486 - harrellsc: 0.4489
# Epoch 46/100
# 26/26 [==============================] - 0s 10ms/step - loss: 24.0469 - harrellsc: 0.4503
# Epoch 47/100
# 26/26 [==============================] - 0s 13ms/step - loss: 24.0452 - harrellsc: 0.4472
# Epoch 48/100
# 26/26 [==============================] - 0s 11ms/step - loss: 24.0435 - harrellsc: 0.4531
# Epoch 49/100
# 26/26 [==============================] - 0s 10ms/step - loss: 24.0419 - harrellsc: 0.4505
# Epoch 50/100
# 26/26 [==============================] - 0s 9ms/step - loss: 24.0403 - harrellsc: 0.4522
# Epoch 51/100
# 26/26 [==============================] - 0s 14ms/step - loss: 24.0387 - harrellsc: 0.4501
# Epoch 52/100
# 26/26 [==============================] - 0s 8ms/step - loss: 24.0371 - harrellsc: 0.4546
# Epoch 53/100
# 26/26 [==============================] - 0s 8ms/step - loss: 24.0356 - harrellsc: 0.4585
# Epoch 54/100
# 26/26 [==============================] - 0s 8ms/step - loss: 24.0341 - harrellsc: 0.4530
# Epoch 55/100
# 26/26 [==============================] - 0s 8ms/step - loss: 24.0326 - harrellsc: 0.4604
# Epoch 56/100
# 26/26 [==============================] - 0s 12ms/step - loss: 24.0311 - harrellsc: 0.4604
# Epoch 57/100
# 26/26 [==============================] - 0s 9ms/step - loss: 24.0297 - harrellsc: 0.4594
# Epoch 58/100
# 26/26 [==============================] - 0s 8ms/step - loss: 24.0282 - harrellsc: 0.4638
# Epoch 59/100
# 26/26 [==============================] - 0s 8ms/step - loss: 24.0268 - harrellsc: 0.4616
# Epoch 60/100
# 26/26 [==============================] - 0s 8ms/step - loss: 24.0254 - harrellsc: 0.4661
# Epoch 61/100
# 26/26 [==============================] - 0s 8ms/step - loss: 24.0240 - harrellsc: 0.4663
# Epoch 62/100
# 26/26 [==============================] - 0s 10ms/step - loss: 24.0227 - harrellsc: 0.4623
# Epoch 63/100
# 26/26 [==============================] - 0s 9ms/step - loss: 24.0213 - harrellsc: 0.4611
# Epoch 64/100
# 26/26 [==============================] - 0s 9ms/step - loss: 24.0200 - harrellsc: 0.4647
# Epoch 65/100
# 26/26 [==============================] - 0s 10ms/step - loss: 24.0187 - harrellsc: 0.4686
# Epoch 66/100
# 26/26 [==============================] - 0s 10ms/step - loss: 24.0174 - harrellsc: 0.4621
# Epoch 67/100
# 26/26 [==============================] - 0s 9ms/step - loss: 24.0161 - harrellsc: 0.4661
# Epoch 68/100
# 26/26 [==============================] - 0s 8ms/step - loss: 24.0148 - harrellsc: 0.4690
# Epoch 69/100
# 26/26 [==============================] - 0s 8ms/step - loss: 24.0135 - harrellsc: 0.4648
# Epoch 70/100
# 26/26 [==============================] - 0s 11ms/step - loss: 24.0123 - harrellsc: 0.4643
# Epoch 71/100
# 26/26 [==============================] - 0s 8ms/step - loss: 24.0110 - harrellsc: 0.4669
# Epoch 72/100
# 26/26 [==============================] - 0s 8ms/step - loss: 24.0098 - harrellsc: 0.4667
# Epoch 73/100
# 26/26 [==============================] - 0s 8ms/step - loss: 24.0086 - harrellsc: 0.4662
# Epoch 74/100
# 26/26 [==============================] - 0s 8ms/step - loss: 24.0074 - harrellsc: 0.4692
# Epoch 75/100
# 26/26 [==============================] - 0s 12ms/step - loss: 24.0062 - harrellsc: 0.4706
# Epoch 76/100
# 26/26 [==============================] - 0s 8ms/step - loss: 24.0050 - harrellsc: 0.4706
# Epoch 77/100
# 26/26 [==============================] - 0s 8ms/step - loss: 24.0038 - harrellsc: 0.4677
# Epoch 78/100
# 26/26 [==============================] - 0s 8ms/step - loss: 24.0027 - harrellsc: 0.4741
# Epoch 79/100
# 26/26 [==============================] - 0s 8ms/step - loss: 24.0015 - harrellsc: 0.4760
# Epoch 80/100
# 26/26 [==============================] - 0s 8ms/step - loss: 24.0004 - harrellsc: 0.4741
# Epoch 81/100
# 26/26 [==============================] - 0s 10ms/step - loss: 23.9992 - harrellsc: 0.4777
# Epoch 82/100
# 26/26 [==============================] - 0s 8ms/step - loss: 23.9981 - harrellsc: 0.4731
# Epoch 83/100
# 26/26 [==============================] - 0s 8ms/step - loss: 23.9970 - harrellsc: 0.4748
# Epoch 84/100
# 26/26 [==============================] - 0s 8ms/step - loss: 23.9959 - harrellsc: 0.4716
# Epoch 85/100
# 26/26 [==============================] - 0s 11ms/step - loss: 23.9948 - harrellsc: 0.4721
# Epoch 86/100
# 26/26 [==============================] - 0s 8ms/step - loss: 23.9937 - harrellsc: 0.4788
# Epoch 87/100
# 26/26 [==============================] - 0s 8ms/step - loss: 23.9926 - harrellsc: 0.4763
# Epoch 88/100
# 26/26 [==============================] - 0s 9ms/step - loss: 23.9916 - harrellsc: 0.4763
# Epoch 89/100
# 26/26 [==============================] - 0s 8ms/step - loss: 23.9905 - harrellsc: 0.4702
# Epoch 90/100
# 26/26 [==============================] - 0s 8ms/step - loss: 23.9894 - harrellsc: 0.4734
# Epoch 91/100
# 26/26 [==============================] - 0s 10ms/step - loss: 23.9884 - harrellsc: 0.4698
# Epoch 92/100
# 26/26 [==============================] - 0s 8ms/step - loss: 23.9874 - harrellsc: 0.4696
# Epoch 93/100
# 26/26 [==============================] - 0s 8ms/step - loss: 23.9863 - harrellsc: 0.4751
# Epoch 94/100
# 26/26 [==============================] - 0s 8ms/step - loss: 23.9853 - harrellsc: 0.4685
# Epoch 95/100
# 26/26 [==============================] - 0s 10ms/step - loss: 23.9843 - harrellsc: 0.4674
# Epoch 96/100
# 26/26 [==============================] - 0s 10ms/step - loss: 23.9833 - harrellsc: 0.4684
# Epoch 97/100
# 26/26 [==============================] - 0s 8ms/step - loss: 23.9823 - harrellsc: 0.4703
# Epoch 98/100
# 26/26 [==============================] - 0s 8ms/step - loss: 23.9813 - harrellsc: 0.4742
# Epoch 99/100
# 26/26 [==============================] - 0s 8ms/step - loss: 23.9803 - harrellsc: 0.4721
# Epoch 100/100
# 26/26 [==============================] - 0s 8ms/step - loss: 23.9793 - harrellsc: 0.4770

# %% [markdown]
# ###  Data batching ###

# %%
def create_dataset(data, labels, indices, shuffle=True, batch_size=64):
    # Create dataset from given indices
    ds_data = tf.data.Dataset.from_tensor_slices(tf.gather(data, indices, axis=0))
    ds_labels = tf.data.Dataset.from_tensor_slices(tf.gather(labels, indices, axis=0))
    ds = tf.data.Dataset.zip((ds_data, ds_labels))

    if shuffle:
        buffer_size = len(indices)
        ds = ds.shuffle(buffer_size)
        
    ds = ds.batch(batch_size)

    for i, batch in enumerate(ds):
        _, l = batch
        events = sum(l[:,1])
        if events < 1.:
            print(f"Warning, 0 events in batch {i}.")
    
    return ds



def perform_k_fold_cross_validation(data, labels, model, n_splits, model_name):
    # Initialize KFold
    kfold = KFold(n_splits=n_splits, shuffle=True, random_state=42)

    for fold, (train_indices, val_indices) in enumerate(kfold.split(data)):
        print(f'Fold {fold + 1}/{n_splits}')
        fold += 1

        # Create train and validation datasets
        ds_train = create_dataset(data, labels, train_indices)
        ds_val = create_dataset(data, labels, val_indices)

        # Fit the model
        history = model.fit(
            ds_train,
            epochs=100,
            validation_data=ds_val,
            callbacks=[tf.keras.callbacks.ReduceLROnPlateau(patience=5, verbose=1)],
        )

        # Plot training metrics for the current fold
        plot_training_metrics(history, model_name, fold)

        # Print validation results for the current fold
        metric_key = f'val_risk_harrellsc' if model_name == 'model_att' else 'val_harrellsc'
        val_loss, val_harrells_c = history.history['val_loss'][-1], history.history[metric_key][-1]
        print(f'Validation Loss: {val_loss:.4f} | Validation Harrell\'s C: {val_harrells_c:.4f}\n')





def plot_training_metrics(history, model_name, fold):
    epochs = list(range(1, len(history.history['loss']) + 1))

    # Create subplots
    fig = sp.make_subplots(rows=1, cols=2, subplot_titles=("Loss", "Harrell's C"))

    # Create a trace for training loss
    trace_train_loss = go.Scatter(x=epochs,
                                  y=history.history['loss'],
                                  mode='lines',
                                  name='Train Loss')

    # Create a trace for validation loss
    trace_val_loss = go.Scatter(x=epochs,
                                y=history.history['val_loss'],
                                mode='lines',
                                name='Validation Loss')

    # Add loss traces to the subplots
    fig.add_trace(trace_train_loss, row=1, col=1)
    fig.add_trace(trace_val_loss, row=1, col=1)

    # Set the metric key based on the model name
    metric_key = 'risk_harrellsc' if model_name == 'model_att' else 'harrellsc'

    # Create a trace for training Harrell's C
    trace_train_harrells_c = go.Scatter(x=epochs,
                                        y=history.history[metric_key],
                                        mode='lines',
                                        name="Train Harrell's C")

    # Create a trace for validation Harrell's C
    trace_val_harrells_c = go.Scatter(x=epochs,
                                      y=history.history[f'val_{metric_key}'],
                                      mode='lines',
                                      name="Validation Harrell's C")

    # Add Harrell's C traces to the subplots
    fig.add_trace(trace_train_harrells_c, row=1, col=2)
    fig.add_trace(trace_val_harrells_c, row=1, col=2)

    # Update xaxis and yaxis titles
    fig.update_xaxes(title_text='Epoch', row=1, col=1)
    fig.update_yaxes(title_text='Loss', row=1, col=1)
    fig.update_xaxes(title_text='Epoch', row=1, col=2)
    fig.update_yaxes(title_text="Harrell's C", row=1, col=2)

    # Update the layout for the plot
    fig.update_layout(title=f'{model_name} Fold {fold} Training Metrics')

    # Show the plot
    fig.show()

# %% [markdown]
# ### Training ###

# %%
# Split the data into train (80%) and test (20%) sets
data_size = data.shape[0]
train_size = int(data_size * 0.8)
indices = np.random.permutation(data_size)
train_indices, test_indices = indices[:train_size], indices[train_size:]

train_data = tf.gather(data, train_indices, axis=0)
test_data = tf.gather(data, test_indices, axis=0)
train_labels = tf.gather(labels, train_indices, axis=0)
test_labels = tf.gather(labels, test_indices, axis=0)

# Use KFold cross-validation on the train set
perform_k_fold_cross_validation(train_data, train_labels, model_att, n_splits=5, model_name='model_att')  # For model_att
# perform_k_fold_cross_validation(train_data, train_labels, model_avg, n_splits=5, model_name='model_avg')  # For model_avg

# %% [markdown]
# ### Evaluation ###

# %%
def evaluate_and_plot_kaplan_meier(model, test_data, test_labels, model_name):
    if model_name == 'model_att':
        risks, _ = model(test_data)
    elif model_name == 'model_avg':
        risks = model(test_data)
    else:
        raise ValueError("Invalid model_name. Choose from 'model_att' and 'model_avg'.")

    risks = risks.numpy()
    cindex = HarrellsC()
    print(f"{model_name} Testing c-index: {cindex(test_labels, risks):.3f}")

    risk_groups = np.squeeze(np.array(risks > np.median(risks), int)) + 1
    km_plot(
        np.array(test_labels),
        groups=risk_groups,
        xlabel="Time",
        ylabel="Survival probability",
        legend=["predicted low risk", "predicted high risk"],
    )

# Evaluate and plot Kaplan-Meier curve for model_att
evaluate_and_plot_kaplan_meier(model_att, test_data, test_labels, model_name='model_att')

# Evaluate and plot Kaplan-Meier curve for model_avg
# evaluate_and_plot_kaplan_meier(model_avg, test_data, test_labels, model_name='model_avg')
